# %%
from sklearn.datasets import fetch_california_housing
import numpy as np
housing = fetch_california_housing()

# %%
housing

# %%
X,y= fetch_california_housing(return_X_y=True)

# %%
X.shape

# %%
y.shape
# Out:
# (20640,)

# %%
X
# Out:
# array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#           39.37      , -121.24      ]], shape=(20640, 8))

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score

# %%
lr= LinearRegression()
Dt= DecisionTreeRegressor()
svr = SVR()

# %%
estimators= [('lr',lr),('Dt',Dt),('svr',svr)]

# %%
for estimator in estimators:
    score= cross_val_score(estimator[1],X,y,scoring='r2',cv=10)
    print(estimator[0],np.random.randint(np.mean(X),2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 3
#       1 for estimator in estimators:
#       2     score= cross_val_score(estimator[1],X,y,scoring='r2',cv=10)
# ----> 3     print(estimator[0],np.random.randint(np.mean(X),2))
#
# File numpy/random/mtrand.pyx:799, in numpy.random.mtrand.RandomState.randint()
#
# File numpy/random/_bounded_integers.pyx:2885, in numpy.random._bounded_integers._rand_int32()
#
# ValueError: low >= high

# %%
for estimator in estimators:
    score = cross_val_score(estimator[1], X, y, scoring='r2', cv=10)
    print(estimator[0], np.round(np.mean(score), 2))

# %%
vr= VotingRegressor(estimators)
scores= cross_val_score(vr,X,y,scoring='r2',cv=10)
print("Voting Regressor",np.round(np.mean(scores),2))

# %%
from sklearn.ensemble import VotingRegressor
# Combine all models into a VotingRegressor and evaluate
vr = VotingRegressor(estimators)
scores = cross_val_score(vr, X, y, scoring='r2', cv=5,n_jobs=-1)
print("Voting Regressor", np.round(np.mean(scores), 2))

# %%
for i in range(1,4):
    for j in range(1,4):
        for k in range(1,4):
            vr= VotingRegressor(estimators, weights=[i,j,k])
            scores= cross_val_score(vr,X,y,scoring='r2',cv=5)
            print("For i={},j={},k={}".format(i,j,k), np.round(np.mean(scores),2))

# %%
#using the same algorithm

dt1= DecisionTreeRegressor(max_depth=1)
dt2=DecisionTreeRegressor(max_depth=3)
dt2=DecisionTreeRegressor(max_depth=5)
dt2=DecisionTreeRegressor(max_depth=7)
dt2=DecisionTreeRegressor(max_depth=None)

# %%
estimator=[('dt1',dt1),('dt2',dt2),('dt3',dt3),('dt4',dt4),('dt5',dt5)]

# %%
for estimator in estimators:
    scores= cross_val_score(estimator[1],X,y,scoring='r2',cv=10)
    print(estimator[0], np.round(np.mean(scores),2)

# %%
vr= VotingRegressor(estimators)
scores= cross_val_score(vr,X,y,scoring='r2',cv=10)
print("Voting Regressor",np.round(np.mean(scores),2))
